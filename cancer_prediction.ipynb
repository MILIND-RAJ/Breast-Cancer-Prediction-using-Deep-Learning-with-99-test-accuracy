# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/data.csv')

# %%
df.head()
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302         M  ...                  0.11890          NaN
# 1    842517         M  ...                  0.08902          NaN
# 2  84300903         M  ...                  0.08758          NaN
# 3  84348301         M  ...                  0.17300          NaN
# 4  84358402         M  ...                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (569, 33)

# %%
x=df

# %%
y=df['diagnosis']

# %%
for i in range(0,len(y)):
  if y[i]=='M':
    y[i]=0
  elif y[i]=='B':
    y[i]=1

# %%
x=x.drop(['id'],axis=1)

# %%
x=x.drop(['diagnosis'],axis=1)

# %%
x=x.drop(['Unnamed: 32'],axis=1)

# %%
x
# Out:
#      radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0          17.99         10.38  ...          0.4601                  0.11890
# 1          20.57         17.77  ...          0.2750                  0.08902
# 2          19.69         21.25  ...          0.3613                  0.08758
# 3          11.42         20.38  ...          0.6638                  0.17300
# 4          20.29         14.34  ...          0.2364                  0.07678
# ..           ...           ...  ...             ...                      ...
# 564        21.56         22.39  ...          0.2060                  0.07115
# 565        20.13         28.25  ...          0.2572                  0.06637
# 566        16.60         28.08  ...          0.2218                  0.07820
# 567        20.60         29.33  ...          0.4087                  0.12400
# 568         7.76         24.54  ...          0.2871                  0.07039
#
# [569 rows x 30 columns]

# %%
x.shape
# Out:
# (569, 30)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from keras.utils import to_categorical
y_train=to_categorical(y_train)
y_test=to_categorical(y_test)

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout
from tensorflow.keras.optimizers import RMSprop,SGD
import tensorflow as tf
from tensorflow import keras
opt = tf.keras.optimizers.Adam(learning_rate=0.001)

# %%
model= Sequential()
model.add(Dense(1024,input_dim=30,activation='relu'))
# model.add(Dropout(0.2))
# model.add(Dense(512,input_dim=30,activation='relu'))
# model.add(Dense(256,input_dim=30,activation='relu'))
# model.add(Dense(128,input_dim=30,activation='relu'))
# model.add(Dense(64,input_dim=30,activation='relu'))
model.add(Dense(2,activation='softmax'))
model.compile(loss='binary_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_88 (Dense)             (None, 1024)              31744
# _________________________________________________________________
# dense_89 (Dense)             (None, 2)                 2050
# =================================================================
# Total params: 33,794
# Trainable params: 33,794
# Non-trainable params: 0
# _________________________________________________________________

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('val_accuracy')>0.99):
      print("\nReached 99% accuracy so cancelling training!")
      self.model.stop_training = True

callbacks = myCallback()

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=300,verbose=2,callbacks=callbacks)
# Out:
# Epoch 1/300
# 15/15 - 0s - loss: 0.0649 - accuracy: 0.9692 - val_loss: 0.0831 - val_accuracy: 0.9649
# Epoch 2/300
# 15/15 - 0s - loss: 0.0733 - accuracy: 0.9670 - val_loss: 0.1261 - val_accuracy: 0.9386
# Epoch 3/300
# 15/15 - 0s - loss: 0.0712 - accuracy: 0.9604 - val_loss: 0.1008 - val_accuracy: 0.9561
# Epoch 4/300
# 15/15 - 0s - loss: 0.0667 - accuracy: 0.9736 - val_loss: 0.0987 - val_accuracy: 0.9649
# Epoch 5/300
# 15/15 - 0s - loss: 0.0959 - accuracy: 0.9648 - val_loss: 0.1046 - val_accuracy: 0.9561
# Epoch 6/300
# 15/15 - 0s - loss: 0.1179 - accuracy: 0.9516 - val_loss: 0.1041 - val_accuracy: 0.9561
# Epoch 7/300
# 15/15 - 0s - loss: 0.0934 - accuracy: 0.9626 - val_loss: 0.0860 - val_accuracy: 0.9649
# Epoch 8/300
# 15/15 - 0s - loss: 0.0688 - accuracy: 0.9692 - val_loss: 0.0908 - val_accuracy: 0.9561
# Epoch 9/300
# 15/15 - 0s - loss: 0.0620 - accuracy: 0.9714 - val_loss: 0.0787 - val_accuracy: 0.9649
# Epoch 10/300
# 15/15 - 0s - loss: 0.0606 - accuracy: 0.9736 - val_loss: 0.0858 - val_accuracy: 0.9649
# Epoch 11/300
# 15/15 - 0s - loss: 0.0802 - accuracy: 0.9670 - val_loss: 0.1159 - val_accuracy: 0.9298
# Epoch 12/300
# 15/15 - 0s - loss: 0.0601 - accuracy: 0.9714 - val_loss: 0.0955 - val_accuracy: 0.9561
# Epoch 13/300
# 15/15 - 0s - loss: 0.0734 - accuracy: 0.9714 - val_loss: 0.0917 - val_accuracy: 0.9561
# Epoch 14/300
# 15/15 - 0s - loss: 0.0797 - accuracy: 0.9692 - val_loss: 0.0827 - val_accuracy: 0.9737
# Epoch 15/300
# 15/15 - 0s - loss: 0.0742 - accuracy: 0.9648 - val_loss: 0.0808 - val_accuracy: 0.9737
# Epoch 16/300
# 15/15 - 0s - loss: 0.0579 - accuracy: 0.9802 - val_loss: 0.1272 - val_accuracy: 0.9386
# Epoch 17/300
# 15/15 - 0s - loss: 0.1163 - accuracy: 0.9538 - val_loss: 0.0778 - val_accuracy: 0.9649
# Epoch 18/300
# 15/15 - 0s - loss: 0.0607 - accuracy: 0.9802 - val_loss: 0.0715 - val_accuracy: 0.9649
# Epoch 19/300
# 15/15 - 0s - loss: 0.0818 - accuracy: 0.9670 - val_loss: 0.1157 - val_accuracy: 0.9561
# Epoch 20/300
# 15/15 - 0s - loss: 0.0923 - accuracy: 0.9604 - val_loss: 0.0688 - val_accuracy: 0.9649
# Epoch 21/300
# 15/15 - 0s - loss: 0.0909 - accuracy: 0.9538 - val_loss: 0.0666 - val_accuracy: 0.9825
# Epoch 22/300
# 15/15 - 0s - loss: 0.0742 - accuracy: 0.9736 - val_loss: 0.0788 - val_accuracy: 0.9649
# Epoch 23/300
# 15/15 - 0s - loss: 0.0764 - accuracy: 0.9560 - val_loss: 0.2690 - val_accuracy: 0.9211
# Epoch 24/300
# 15/15 - 0s - loss: 0.0751 - accuracy: 0.9670 - val_loss: 0.0793 - val_accuracy: 0.9649
# Epoch 25/300
# 15/15 - 0s - loss: 0.0682 - accuracy: 0.9670 - val_loss: 0.0723 - val_accuracy: 0.9649
# Epoch 26/300
# 15/15 - 0s - loss: 0.0573 - accuracy: 0.9758 - val_loss: 0.1342 - val_accuracy: 0.9386
# Epoch 27/300
# 15/15 - 0s - loss: 0.1165 - accuracy: 0.9516 - val_loss: 0.0844 - val_accuracy: 0.9649
# Epoch 28/300
# 15/15 - 0s - loss: 0.0884 - accuracy: 0.9582 - val_loss: 0.0728 - val_accuracy: 0.9737
# Epoch 29/300
# 15/15 - 0s - loss: 0.0601 - accuracy: 0.9758 - val_loss: 0.0981 - val_accuracy: 0.9649
# Epoch 30/300
# 15/15 - 0s - loss: 0.0544 - accuracy: 0.9780 - val_loss: 0.0790 - val_accuracy: 0.9649
# Epoch 31/300
# 15/15 - 0s - loss: 0.0695 - accuracy: 0.9780 - val_loss: 0.0659 - val_accuracy: 0.9649
# Epoch 32/300
# 15/15 - 0s - loss: 0.0559 - accuracy: 0.9758 - val_loss: 0.0853 - val_accuracy: 0.9825
# Epoch 33/300
# 15/15 - 0s - loss: 0.1430 - accuracy: 0.9473 - val_loss: 0.0574 - val_accuracy: 0.9737
# Epoch 34/300
# 15/15 - 0s - loss: 0.1171 - accuracy: 0.9473 - val_loss: 0.1513 - val_accuracy: 0.9298
# Epoch 35/300
# 15/15 - 0s - loss: 0.0804 - accuracy: 0.9626 - val_loss: 0.1266 - val_accuracy: 0.9474
# Epoch 36/300
# 15/15 - 0s - loss: 0.0627 - accuracy: 0.9802 - val_loss: 0.0718 - val_accuracy: 0.9737
# Epoch 37/300
# 15/15 - 0s - loss: 0.0648 - accuracy: 0.9758 - val_loss: 0.1094 - val_accuracy: 0.9386
# Epoch 38/300
# 15/15 - 0s - loss: 0.0559 - accuracy: 0.9736 - val_loss: 0.1559 - val_accuracy: 0.9386
# Epoch 39/300
# 15/15 - 0s - loss: 0.0559 - accuracy: 0.9780 - val_loss: 0.0622 - val_accuracy: 0.9649
# Epoch 40/300
# 15/15 - 0s - loss: 0.0654 - accuracy: 0.9714 - val_loss: 0.1039 - val_accuracy: 0.9561
# Epoch 41/300
# 15/15 - 0s - loss: 0.0661 - accuracy: 0.9670 - val_loss: 0.0662 - val_accuracy: 0.9825
# Epoch 42/300
# 15/15 - 0s - loss: 0.0595 - accuracy: 0.9692 - val_loss: 0.0766 - val_accuracy: 0.9649
# Epoch 43/300
# 15/15 - 0s - loss: 0.0611 - accuracy: 0.9692 - val_loss: 0.0798 - val_accuracy: 0.9649
# Epoch 44/300
# 15/15 - 0s - loss: 0.0739 - accuracy: 0.9648 - val_loss: 0.0707 - val_accuracy: 0.9649
# Epoch 45/300
# 15/15 - 0s - loss: 0.0627 - accuracy: 0.9736 - val_loss: 0.1048 - val_accuracy: 0.9649
# Epoch 46/300
# 15/15 - 0s - loss: 0.0607 - accuracy: 0.9736 - val_loss: 0.1107 - val_accuracy: 0.9474
# Epoch 47/300
# 15/15 - 0s - loss: 0.0605 - accuracy: 0.9736 - val_loss: 0.0974 - val_accuracy: 0.9649
# Epoch 48/300
# 15/15 - 0s - loss: 0.1138 - accuracy: 0.9626 - val_loss: 0.1565 - val_accuracy: 0.9298
# Epoch 49/300
# 15/15 - 0s - loss: 0.0616 - accuracy: 0.9714 - val_loss: 0.0829 - val_accuracy: 0.9649
# Epoch 50/300
# 15/15 - 0s - loss: 0.0617 - accuracy: 0.9714 - val_loss: 0.1888 - val_accuracy: 0.9386
# Epoch 51/300
# 15/15 - 0s - loss: 0.0832 - accuracy: 0.9648 - val_loss: 0.0822 - val_accuracy: 0.9649
# Epoch 52/300
# 15/15 - 0s - loss: 0.0562 - accuracy: 0.9758 - val_loss: 0.0639 - val_accuracy: 0.9737
# Epoch 53/300
# 15/15 - 0s - loss: 0.0606 - accuracy: 0.9802 - val_loss: 0.1301 - val_accuracy: 0.9386
# Epoch 54/300
# 15/15 - 0s - loss: 0.0792 - accuracy: 0.9626 - val_loss: 0.0707 - val_accuracy: 0.9649
# Epoch 55/300
# 15/15 - 0s - loss: 0.0961 - accuracy: 0.9516 - val_loss: 0.1397 - val_accuracy: 0.9386
# Epoch 56/300
# 15/15 - 0s - loss: 0.0631 - accuracy: 0.9758 - val_loss: 0.1087 - val_accuracy: 0.9474
# Epoch 57/300
# 15/15 - 0s - loss: 0.0588 - accuracy: 0.9824 - val_loss: 0.1061 - val_accuracy: 0.9649
# Epoch 58/300
# 15/15 - 0s - loss: 0.0543 - accuracy: 0.9780 - val_loss: 0.0764 - val_accuracy: 0.9825
# Epoch 59/300
# 15/15 - 0s - loss: 0.0745 - accuracy: 0.9692 - val_loss: 0.1404 - val_accuracy: 0.9298
# Epoch 60/300
# 15/15 - 0s - loss: 0.1051 - accuracy: 0.9538 - val_loss: 0.2501 - val_accuracy: 0.9298
# Epoch 61/300
# 15/15 - 0s - loss: 0.3164 - accuracy: 0.8967 - val_loss: 0.0902 - val_accuracy: 0.9737
# Epoch 62/300
# 15/15 - 0s - loss: 0.1333 - accuracy: 0.9429 - val_loss: 0.0792 - val_accuracy: 0.9649
# Epoch 63/300
# 15/15 - 0s - loss: 0.0695 - accuracy: 0.9736 - val_loss: 0.0724 - val_accuracy: 0.9561
# Epoch 64/300
# 15/15 - 0s - loss: 0.0675 - accuracy: 0.9736 - val_loss: 0.0941 - val_accuracy: 0.9737
# Epoch 65/300
# 15/15 - 0s - loss: 0.1242 - accuracy: 0.9516 - val_loss: 0.1620 - val_accuracy: 0.9298
# Epoch 66/300
# 15/15 - 0s - loss: 0.0838 - accuracy: 0.9692 - val_loss: 0.0684 - val_accuracy: 0.9649
# Epoch 67/300
# 15/15 - 0s - loss: 0.0637 - accuracy: 0.9714 - val_loss: 0.1014 - val_accuracy: 0.9561
# Epoch 68/300
# 15/15 - 0s - loss: 0.0796 - accuracy: 0.9670 - val_loss: 0.0930 - val_accuracy: 0.9561
# Epoch 69/300
# 15/15 - 0s - loss: 0.0679 - accuracy: 0.9780 - val_loss: 0.0966 - val_accuracy: 0.9649
# Epoch 70/300
# 15/15 - 0s - loss: 0.0534 - accuracy: 0.9758 - val_loss: 0.1538 - val_accuracy: 0.9298
# Epoch 71/300
# 15/15 - 0s - loss: 0.0834 - accuracy: 0.9670 - val_loss: 0.0861 - val_accuracy: 0.9649
# Epoch 72/300
# 15/15 - 0s - loss: 0.0637 - accuracy: 0.9714 - val_loss: 0.0634 - val_accuracy: 0.9737
# Epoch 73/300
# 15/15 - 0s - loss: 0.0597 - accuracy: 0.9714 - val_loss: 0.0868 - val_accuracy: 0.9561
# Epoch 74/300
# 15/15 - 0s - loss: 0.0827 - accuracy: 0.9670 - val_loss: 0.0724 - val_accuracy: 0.9912
#
# Reached 99% accuracy so cancelling training!

# %%
pred=model.predict_classes(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
model.save('breast_cancer.h5')

# %%
from google.colab import files
files.download("breast_cancer.h5")
